# %%
from __future__ import annotations
from pathlib import Path
import pandas as pd
import numpy as np

# %%
from pathlib import Path
import pandas as pd

def ensure_dir(p: Path):
    p.mkdir(parents=True, exist_ok=True)
    return p

def read_csv(path: str | Path, **kw) -> pd.DataFrame:
    return pd.read_csv(path, **kw)

def to_parquet(df, path: str | Path):
    path = Path(path)
    ensure_dir(path.parent)
    df.to_parquet(path, index=False)
    return str(path)

# %% [markdown]
# # Load metadata

# %%
metadata_1 = r"C:\bachkhoahanoi\2025.1\Recommend System\data\raw\sweettv-tv-program-recommender\export_arh_11-20-final.csv"
df_metadata_1 = read_csv(metadata_1)
df_metadata_1.head(10)
# Out:
#    channel_id channel_title           start_time  duration  \
# 0           3           1+1  09.03.2020 06:00:00      6000
# 1           3           1+1  09.03.2020 07:40:00      5400
# 2           3           1+1  09.03.2020 09:10:00      8400
# 3           3           1+1  09.03.2020 11:30:00     28800
# 4           3           1+1  09.03.2020 19:30:00      2700
# 5           3           1+1  09.03.2020 20:15:00     14100
# 6           3           1+1  10.03.2020 00:10:00      6900
# 7           3           1+1  10.03.2020 02:05:00      5700
# 8           3           1+1  10.03.2020 03:40:00      7200
# 9           3           1+1  10.03.2020 05:40:00      3000
#
#                                tv_show_title  tv_show_id tv_show_category  \
# 0          'Жизнь известных людей', 2 сезон.           0           Другое
# 1                             'ТСН. Неделя'.     2400480             Инфо
# 2     'Голос страны', 10 сезон, 8 эп. 'Бои'.      700475      Развлечения
# 3               Т/с 'По праву любви', 1-8 с.           0          Сериалы
# 4                                       ТСН.     2400480             Инфо
# 5  Премьера. Х/ф 'Любовь без памяти', 1-4 с.    90082508           Фильмы
# 6                   Х/ф 'Сделано в Америке'.    90080911           Фильмы
# 7             Т/с 'По праву любви', 1 и 2 с.           0          Сериалы
# 8                               Т/с 'Школа'.    10003080          Сериалы
# 9                                       ТСН.     2400480             Инфо
#
#        tv_show_genre_1 tv_show_genre_2 tv_show_genre_3 year_of_production  \
# 0                  NaN             NaN             NaN                NaN
# 1  общество и политика             NaN             NaN               1997
# 2               музыка             NaN             NaN               2010
# 3                  NaN             NaN             NaN                NaN
# 4  общество и политика             NaN             NaN               1997
# 5            мелодрама             NaN             NaN               2019
# 6               боевик  биографический         комедия               2017
# 7                  NaN             NaN             NaN                NaN
# 8                драма       мелодрама             NaN               2018
# 9  общество и политика             NaN             NaN               1997
#
#          director                                       actors
# 0             NaN                                          NaN
# 1             NaN                                          NaN
# 2             NaN                                          NaN
# 3             NaN                                          NaN
# 4             NaN                                          NaN
# 5  Андрей Комаров       Алина Гросу, Артем Алексеев, Ирина Мак
# 6      Даг Лаймэн            Том Круз, Донал Глисон, Сара Райт
# 7             NaN                                          NaN
# 8   Сергей Уманец  Янина Андреева, Никита Вакулюк, Алёна Курта
# 9             NaN                                          NaN

# %%
df_metadata_1.shape
# Out:
# (1074235, 13)

# %%
metadata_2 = r"C:\bachkhoahanoi\2025.1\Recommend System\data\raw\sweettv-tv-program-recommender\export_arh_21-30-final.csv"
df_metadata_2 = read_csv(metadata_2)
df_metadata_2.head(10)
# Out:
#    channel_id channel_title           start_time  duration  \
# 0           3           1+1  18.05.2020 06:30:00      1800
# 1           3           1+1  18.05.2020 07:00:00       600
# 2           3           1+1  18.05.2020 07:10:00      3000
# 3           3           1+1  18.05.2020 08:00:00       600
# 4           3           1+1  18.05.2020 08:10:00      3000
# 5           3           1+1  18.05.2020 09:00:00       600
# 6           3           1+1  18.05.2020 09:10:00       900
# 7           3           1+1  18.05.2020 09:25:00      6600
# 8           3           1+1  18.05.2020 11:15:00      2700
# 9           3           1+1  18.05.2020 12:00:00      1200
#
#                                        tv_show_title  tv_show_id  \
# 0  'Завтрак с 1+1'. Информационно-развлекательная...       20088
# 1                                               ТСН.     2400480
# 2  'Завтрак с 1+1'. Информационно-развлекательная...       20088
# 3                                               ТСН.     2400480
# 4  'Завтрак с 1+1'. Информационно-развлекательная...       20088
# 5                                               ТСН.     2400480
# 6  'Завтрак с 1+1'. Информационно-развлекательная...       20088
# 7      'Жизнь известных людей', 2 сезон, 11 и 26 эп.           0
# 8                          'Дорогой, мы переезжаем'.           0
# 9                                               ТСН.     2400480
#
#   tv_show_category           tv_show_genre_1 tv_show_genre_2 tv_show_genre_3  \
# 0      Развлечения  информация (комплексная)             NaN             NaN
# 1             Инфо       общество и политика             NaN             NaN
# 2      Развлечения  информация (комплексная)             NaN             NaN
# 3             Инфо       общество и политика             NaN             NaN
# 4      Развлечения  информация (комплексная)             NaN             NaN
# 5             Инфо       общество и политика             NaN             NaN
# 6      Развлечения  информация (комплексная)             NaN             NaN
# 7           Другое                       NaN             NaN             NaN
# 8           Другое                       NaN             NaN             NaN
# 9             Инфо       общество и политика             NaN             NaN
#
#   year_of_production director actors
# 0              1996-      NaN    NaN
# 1               1997      NaN    NaN
# 2              1996-      NaN    NaN
# 3               1997      NaN    NaN
# 4              1996-      NaN    NaN
# 5               1997      NaN    NaN
# 6              1996-      NaN    NaN
# 7                NaN      NaN    NaN
# 8                NaN      NaN    NaN
# 9               1997      NaN    NaN

# %%
df_metadata_2.shape
# Out:
# (1074394, 13)

# %%
df_metadata_2.columns
# Out:
# Index(['channel_id', 'channel_title', 'start_time', 'duration',
#        'tv_show_title', 'tv_show_id', 'tv_show_category', 'tv_show_genre_1',
#        'tv_show_genre_2', 'tv_show_genre_3', 'year_of_production', 'director',
#        'actors'],
#       dtype='object')

# %% [markdown]
# | Thuộc tính     | Encode tốt nhất                 | Lý do                          |
# | -------------- | ------------------------------- | ------------------------------ |
# | **category**   | One-hot                         | ít giá trị, đơn nhãn           |
# | **genre**      | Multi-hot                       | multi-label, số lượng vừa phải |
# | **director**   | ID + embedding **hoặc** one-hot | tuỳ số lượng                   |
# | **actors**     | Multi-hot (top-K)               | multi-label, nhiều người       |
# | **title**      | text embedding                  | one-hot hoặc ID rất yếu        |
# | **tv_show_id** | ID                              | dùng cho CF                    |

# %%
import re
import json
import pandas as pd


def _parse_meta_start(series: pd.Series) -> pd.Series:
    """
    Parse datetime theo format chuẩn 'dd.mm.YYYY HH:MM:SS'
    và tự động sửa các lỗi kiểu '21:' hoặc '21' hoặc '21:05'.
    """
    def fix_time(s: str) -> str:
        if not isinstance(s, str):
            return s

        s = s.strip()
        # Nếu thiếu giờ -> thêm 00:00:00
        if re.match(r"^\d{2}\.\d{2}\.\d{4}$", s):
            return s + " 00:00:00"
        # Nếu dạng 21: -> thêm 00:00
        if re.match(r"^\d{2}\.\d{2}\.\d{4} \d{1,2}:$", s):
            return s + "00:00"
        # Nếu dạng 21 -> thêm :00:00
        if re.match(r"^\d{2}\.\d{2}\.\d{4} \d{1,2}$", s):
            return s + ":00:00"
        # Nếu dạng HH:MM -> thêm :00
        if re.match(r"^\d{2}\.\d{2}\.\d{4} \d{1,2}:\d{2}$", s):
            return s + ":00"

        return s

    # Sửa lỗi từng giá trị
    series = series.astype(str).apply(fix_time)
    # Parse theo đúng format
    return pd.to_datetime(series, format="%d.%m.%Y %H:%M:%S", errors="coerce")



def parse_year(x):
    """
    Chuẩn hóa year_of_production:
    - '1990–2020' -> 1990
    - '2005-' -> 2005
    - '2003' -> 2003
    - convert to int
    """
    try:
        x = str(x).replace("–", "-").strip()
        if "-" in x:
            x = x.split("-")[0]
        return int(x)
    except:
        return None



def load_meta(dfs):
    """
    Load metadata nhẹ để dùng cho các mô hình CF/Hybrid:
    - Không multi-hot
    - Không unique encode
    - Chỉ tạo list genres / actors
    - Không gây nặng RAM
    """

    # Gộp file
    meta = pd.concat(dfs, ignore_index=True)

    # rename
    meta = meta.rename(columns={"channel_id": "vsetv_id"})

    # Parse thời gian
    meta["start_time"] = _parse_meta_start(meta["start_time"])
    meta["duration"] = pd.to_numeric(meta["duration"], errors="coerce").fillna(0)
    meta["prog_end"] = meta["start_time"] + pd.to_timedelta(meta["duration"], unit="s")

    # # Clean text các cột
    # text_cols = [
    #     "tv_show_title", "tv_show_category",
    #     "tv_show_genre_1","tv_show_genre_2","tv_show_genre_3",
    #     "director", "actors", "year_of_production"
    # ]
    # for c in text_cols:
    #     meta[c] = meta[c].fillna("").astype(str).lower().str.strip()

    # ===== GENRES LIST =====
    meta["genres_list"] = meta[
        ["tv_show_genre_1", "tv_show_genre_2", "tv_show_genre_3"]
    ].apply(lambda r: [g for g in r if g not in ("", "nan", None)], axis=1)

    # ===== ACTORS LIST =====
    def clean_actors(x):
        if not isinstance(x, str):
            return []            # float, nan, None, số → trả về list rỗng
        x = x.replace(";", ",")
        parts = x.split(",")
        return [p.strip() for p in parts if p.strip()]

    meta["actors_list"] = meta["actors"].apply(clean_actors)

    # ===== YEAR NORMALIZE =====
    meta["year_clean"] = meta["year_of_production"].apply(parse_year)

    # fill missing bằng median
    median_year = (
        meta["year_clean"].median() if meta["year_clean"].notna().any() else 2010
    )
    meta["year_clean"] = meta["year_clean"].fillna(median_year).astype(int)

    # Min-max normalize
    y_min, y_max = meta["year_clean"].min(), meta["year_clean"].max()
    meta["year_norm"] = (meta["year_clean"] - y_min) / (y_max - y_min)

    # ===== TRẢ VỀ RAW METADATA =====
    return meta[
        [
            "vsetv_id", "tv_show_id",
            "tv_show_category",
            "director", "genres_list", "actors_list",
            "start_time", "prog_end", "duration","year_of_production"
        ]
    ]

# %%
metadatas = []
metadatas.append(df_metadata_1)
metadatas.append(df_metadata_2)
meta_df = load_meta(metadatas)

# %%
meta_df.head(10)
# Out:
#    vsetv_id  tv_show_id tv_show_category        director  \
# 0         3           0           Другое             NaN
# 1         3     2400480             Инфо             NaN
# 2         3      700475      Развлечения             NaN
# 3         3           0          Сериалы             NaN
# 4         3     2400480             Инфо             NaN
# 5         3    90082508           Фильмы  Андрей Комаров
# 6         3    90080911           Фильмы      Даг Лаймэн
# 7         3           0          Сериалы             NaN
# 8         3    10003080          Сериалы   Сергей Уманец
# 9         3     2400480             Инфо             NaN
#
#                          genres_list  \
# 0                    [nan, nan, nan]
# 1    [общество и политика, nan, nan]
# 2                 [музыка, nan, nan]
# 3                    [nan, nan, nan]
# 4    [общество и политика, nan, nan]
# 5              [мелодрама, nan, nan]
# 6  [боевик, биографический, комедия]
# 7                    [nan, nan, nan]
# 8            [драма, мелодрама, nan]
# 9    [общество и политика, nan, nan]
#
#                                      actors_list          start_time  \
# 0                                             [] 2020-03-09 06:00:00
# 1                                             [] 2020-03-09 07:40:00
# 2                                             [] 2020-03-09 09:10:00
# 3                                             [] 2020-03-09 11:30:00
# 4                                             [] 2020-03-09 19:30:00
# 5       [Алина Гросу, Артем Алексеев, Ирина Мак] 2020-03-09 20:15:00
# 6            [Том Круз, Донал Глисон, Сара Райт] 2020-03-10 00:10:00
# 7                                             [] 2020-03-10 02:05:00
# 8  [Янина Андреева, Никита Вакулюк, Алёна Курта] 2020-03-10 03:40:00
# 9                                             [] 2020-03-10 05:40:00
#
#              prog_end  duration year_of_production
# 0 2020-03-09 07:40:00      6000                NaN
# 1 2020-03-09 09:10:00      5400               1997
# 2 2020-03-09 11:30:00      8400               2010
# 3 2020-03-09 19:30:00     28800                NaN
# 4 2020-03-09 20:15:00      2700               1997
# 5 2020-03-10 00:10:00     14100               2019
# 6 2020-03-10 02:05:00      6900               2017
# 7 2020-03-10 03:40:00      5700                NaN
# 8 2020-03-10 05:40:00      7200               2018
# 9 2020-03-10 06:30:00      3000               1997

# %%
meta_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2148629 entries, 0 to 2148628
# Data columns (total 10 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   vsetv_id            int64
#  1   tv_show_id          int64
#  2   tv_show_category    object
#  3   director            object
#  4   genres_list         object
#  5   actors_list         object
#  6   start_time          datetime64[ns]
#  7   prog_end            datetime64[ns]
#  8   duration            int64
#  9   year_of_production  object
# dtypes: datetime64[ns](2), int64(3), object(5)
# memory usage: 163.9+ MB

# %%
# ---- Robust project root detection ----
def get_project_root() -> Path:
    # 1) Script mode
    if "__file__" in globals():
        return Path(__file__).resolve().parents[1]  # src/.. -> project root
    # 2) Notebook/REPL: dò từ CWD ngược lên cho đến khi thấy both 'data' và 'src'
    cwd = Path.cwd().resolve()
    for p in [cwd, *cwd.parents]:
        if (p / "data").exists() and (p / "src").exists():
            return p
    # 3) Fallback: dùng CWD
    return cwd

PROJECT_ROOT = get_project_root()
DATA_DIR = PROJECT_ROOT / "data" / "clean"   # hoặc "clean" nếu bạn muốn
DATA_DIR.mkdir(parents=True, exist_ok=True)

OUT_META = DATA_DIR / "metadata.parquet"

meta_df.to_parquet(OUT_META, index=False)

# %%
import matplotlib.pyplot as plt

# Làm sạch & chuẩn bị dữ liệu vẽ
dur = pd.to_numeric(meta_df["duration"], errors="coerce")
dur = dur[dur > 0].dropna()                 # chỉ giữ duration dương
dur_min = dur / 60.0                        # đổi sang phút

print("Tóm tắt duration (phút)")
dur_min.describe()
# Out:
# Tóm tắt duration (phút)
# count    2.148628e+06
# mean     3.742750e+01
# std      4.438015e+01
# min      1.000000e+00
# 25%      1.000000e+01
# 50%      2.500000e+01
# 75%      5.000000e+01
# max      1.440000e+03
# Name: duration, dtype: float64

# %%
# Vẽ histogram duration (phút) – p99 clipped
plt.figure(figsize=(8,5))
plt.hist(dur_min, bins=50, edgecolor="black")
plt.title("Histogram of program duration (minutes, capped at p99)")
plt.xlabel("duration (minutes)")
plt.ylabel("count")
plt.show()

# %% [markdown]
# # Load file logs

# %%
logs = r"C:\bachkhoahanoi\2025.1\Recommend System\data\raw\sweettv-tv-program-recommender\dataset11-30.csv"
df_logs = read_csv(logs)
df_logs.head(10)
# Out:
#                 user_id  vsetv_id           start_time            stop_time  \
# 0   3398461054087191302         6  2020-03-09 00:00:02  2020-03-09 00:01:53
# 1  17226860011138219284       353  2020-03-09 00:00:02  2020-03-09 00:03:26
# 2  18417531283109304442       332  2020-03-09 00:00:05  2020-03-09 00:01:26
# 3   3677642666679759206         7  2020-03-09 00:00:08  2020-03-09 01:07:41
# 4  15105343836194894915       108  2020-03-09 00:00:10  2020-03-09 00:02:34
# 5  18081325105171528512       921  2020-03-09 00:00:11  2020-03-09 00:05:41
# 6   8504965706466181080      1249  2020-03-09 00:00:13  2020-03-09 00:32:58
# 7   7072476312452226836       777  2020-03-09 00:00:13  2020-03-09 01:11:53
# 8   5650752551262273512       535  2020-03-09 00:00:14  2020-03-09 00:21:51
# 9  17507504718632061872       397  2020-03-09 00:00:16  2020-03-09 00:08:47
#
#    duraton
# 0      111
# 1      204
# 2       81
# 3     4053
# 4      144
# 5      330
# 6     1965
# 7     4300
# 8     1297
# 9      511

# %%
df_logs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5821987 entries, 0 to 5821986
# Data columns (total 5 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   user_id     uint64
#  1   vsetv_id    int64
#  2   start_time  object
#  3   stop_time   object
#  4   duraton     int64
# dtypes: int64(2), object(2), uint64(1)
# memory usage: 222.1+ MB

# %%
df_logs.describe()
# Out:
#             user_id      vsetv_id       duraton
# count  5.821987e+06  5.821987e+06  5.821987e+06
# mean   9.294733e+18  4.980913e+02  1.480459e+03
# std    5.200603e+18  5.728140e+02  3.123737e+03
# min    2.244466e+15  3.000000e+00  6.100000e+01
# 25%    4.928752e+18  6.000000e+00  1.330000e+02
# 50%    9.249745e+18  1.750000e+02  3.960000e+02
# 75%    1.386442e+19  9.350000e+02  1.452000e+03
# max    1.844383e+19  1.531000e+03  3.421450e+05

# %%
def load_logs(df: pd.DataFrame | Path) -> pd.DataFrame:
    """
    Đọc file logs (dataset11-30.csv), chuẩn hoá cột và lọc lượt xem ngắn.
    - Đổi tên: stop_time->end_time, duraton->duration
    - Parse datetime cho start_time, end_time
    """
    df = df.rename(columns={"stop_time": "end_time", "duraton": "duration"}).copy()

    # Bắt buộc có các cột tối thiểu
    required = {"user_id", "vsetv_id", "start_time", "end_time", "duration"}
    missing = required - set(df.columns)
    if missing:
        raise ValueError(f"Missing columns in logs: {missing}")

    # Parse datetime cho logs (thường đã ở dạng ISO)
    df["start_time"] = pd.to_datetime(df["start_time"], errors="raise", utc=False)
    df["end_time"]   = pd.to_datetime(df["end_time"],   errors="raise", utc=False)

    # Duration numeric & filter
    df["duration"] = pd.to_numeric(df["duration"], errors="coerce").fillna(0).astype(int)

    # Đổi tên cột nhất quán downstream
    df = df.rename(columns={
        "start_time": "start_time_view",
        "end_time":   "end_time_view",
        "duration":   "duration_view",
    })
    return df[["user_id", "vsetv_id", "start_time_view", "end_time_view", "duration_view"]]

# %%
log = load_logs(df_logs)

# %%
log.head(5)
# Out:
#                 user_id  vsetv_id     start_time_view       end_time_view  \
# 0   3398461054087191302         6 2020-03-09 00:00:02 2020-03-09 00:01:53
# 1  17226860011138219284       353 2020-03-09 00:00:02 2020-03-09 00:03:26
# 2  18417531283109304442       332 2020-03-09 00:00:05 2020-03-09 00:01:26
# 3   3677642666679759206         7 2020-03-09 00:00:08 2020-03-09 01:07:41
# 4  15105343836194894915       108 2020-03-09 00:00:10 2020-03-09 00:02:34
#
#    duration_view
# 0            111
# 1            204
# 2             81
# 3           4053
# 4            144

# %% [markdown]
# # Ghép log ↔ lịch phát sóng theo kênh + khoảng thời gian (interval join)
# - logs: mỗi dòng là một lượt xem của user trên một kênh (vsetv_id) với khoảng thời gian [start_time_view, end_time_view].
# - meta: lịch phát sóng của cùng kênh, mỗi dòng là một tập/chương trình với khoảng thời gian [start_time, prog_end].
# - Mục tiêu: với mỗi lượt xem, tìm một chương trình trong lịch phát sóng trên cùng kênh mà chồng lấn (overlap) với lượt xem lớn nhất, rồi gán tv_show_id cho lượt xem đó.
# ![Alt text](image.png)

# %%
from __future__ import annotations
import argparse
from pathlib import Path
import numpy as np
import pandas as pd

# %%
def _pick_overlap(logs_ch: pd.DataFrame, meta_ch: pd.DataFrame) -> pd.DataFrame:
    """
    Với mỗi lượt xem (view) trên 1 kênh:
      - Chẻ view theo ranh giới chương trình trong meta_ch (đã sort theo start_time).
      - Trả về nhiều hàng (segment) cho một view nếu view bắc cầu >1 show.
    Yêu cầu meta_ch có các cột: ["vsetv_id","start_time","prog_end","tv_show_id"]
    và đã lọc tv_show_id != 0 từ trước.
    """
    if logs_ch.empty or meta_ch.empty:
        return pd.DataFrame(columns=[
            "user_id","tv_show_id","vsetv_id",
            "start_time_view","end_time_view","duration_view",
            "seg_start","seg_end","overlap_s","show_duration_s",
            "view_id","seg_idx"
        ])

    # Bảo đảm sort theo start_time để tìm kiếm nhị phân
    meta_ch = meta_ch.sort_values("start_time").reset_index(drop=True)

    # Chuẩn bị mảng nhanh
    # MẢNG NHANH – ép kiểu an toàn
    m_start = meta_ch["start_time"].to_numpy(dtype="datetime64[ns]")
    m_end   = meta_ch["prog_end"].to_numpy(dtype="datetime64[ns]")
    m_tid   = pd.to_numeric(meta_ch["tv_show_id"], errors="coerce").to_numpy()
    m_tid   = np.ravel(m_tid)  # phẳng 1-D

    # Gán view_id
    logs_ch = logs_ch.copy()
    logs_ch["view_id"] = np.arange(len(logs_ch), dtype=np.int64)

    out_rows = []
    for _, row in logs_ch.iterrows():
        v_start = np.datetime64(row["start_time_view"])
        v_end   = np.datetime64(row["end_time_view"])
        if v_end <= v_start:
            continue

        # Tìm show có start_time <= v_start (vị trí bắt đầu duyệt)
        # searchsorted trả vị trí chèn để giữ m_start tăng dần
        # side='right' rồi -1 để lấy phần tử <= v_start
        i = np.searchsorted(m_start, v_start, side="right") - 1
        if i < 0:
            i = 0

        seg_idx = 0
        # Duyệt các show cho đến khi start_time_show >= v_end
        # (vì những show bắt đầu sau v_end sẽ không thể overlap)
        n = len(meta_ch)
        while i < n and m_start[i] < v_end:
            s_show = m_start[i]
            e_show = m_end[i]
            # Nếu show kết thúc trước v_start thì nhảy tiếp
            if e_show <= v_start:
                i += 1
                continue
            # Nếu show bắt đầu sau v_end thì dừng
            if s_show >= v_end:
                break

            # Tính đoạn overlap giữa view và show
            seg_start = max(v_start, s_show)
            seg_end   = min(v_end, e_show)
            if seg_end > seg_start:
                overlap_s = int((seg_end - seg_start) / np.timedelta64(1, "s"))
                show_duration_s = int((e_show - s_show) / np.timedelta64(1, "s"))

                # LẤY tv_show_id an toàn
                tid_val = m_tid[i]
                if isinstance(tid_val, (np.ndarray, list)):
                    tid_val = np.ravel(tid_val)[0]
                if pd.isna(tid_val):
                    i += 1
                    continue
                tid_val = int(tid_val)

                out_rows.append({
                    "user_id": row["user_id"],
                    "tv_show_id": int(m_tid[i]),
                    "vsetv_id": row["vsetv_id"],
                    "start_time_view": row["start_time_view"],
                    "end_time_view": row["end_time_view"],
                    "duration_view": row["duration_view"],
                    "seg_start": pd.Timestamp(seg_start),
                    "seg_end": pd.Timestamp(seg_end),
                    "overlap_s": overlap_s,
                    "show_duration_s": show_duration_s,
                    "view_id": row["view_id"],
                    "seg_idx": seg_idx,
                })
                seg_idx += 1

            # Sang show kế tiếp
            i += 1

    if not out_rows:
        return pd.DataFrame(columns=[
            "user_id","tv_show_id","vsetv_id",
            "start_time_view","end_time_view","duration_view",
            "seg_start","seg_end","overlap_s","show_duration_s",
            "view_id","seg_idx"
        ])
    return pd.DataFrame(out_rows)

def interval_join_logs_with_program(logs: pd.DataFrame, meta: pd.DataFrame) -> pd.DataFrame:
    out = []
    for vid, logs_ch in logs.groupby("vsetv_id", sort=False):
        meta_ch = meta[meta["vsetv_id"] == vid]
        matched = _pick_overlap(logs_ch, meta_ch)
        if not matched.empty:
            out.append(matched)
    if not out:
        return pd.DataFrame(columns=[
            "user_id","tv_show_id","vsetv_id",
            "start_time_view","end_time_view","duration_view",
            "seg_start","seg_end","overlap_s","show_duration_s",
            "view_id","seg_idx"
        ])
    return pd.concat(out, ignore_index=True)

# %%
joined = interval_join_logs_with_program(log, meta_df)

# %%
joined.head(10)
# Out:
#                 user_id  tv_show_id  vsetv_id     start_time_view  \
# 0    245033728947691708     5200464         6 2020-03-09 02:36:33
# 1  16732082036693231547     5200464         6 2020-03-09 03:15:44
# 2  16732082036693231547    10002893         6 2020-03-09 03:15:44
# 3  12064862736733875748     5200464         6 2020-03-09 03:16:34
# 4   6075271130876439659     5200464         6 2020-03-09 03:19:16
# 5  10077667190354238027     5200464         6 2020-03-09 03:19:25
# 6  12064862736733875748     5200464         6 2020-03-09 03:27:19
# 7  10077667190354238027     5200464         6 2020-03-09 03:42:30
# 8  15124852834920975918     5200464         6 2020-03-09 03:56:47
# 9  16424897552696285989     5200464         6 2020-03-09 04:12:09
#
#         end_time_view  duration_view           seg_start             seg_end  \
# 0 2020-03-09 03:28:24           3111 2020-03-09 03:20:00 2020-03-09 03:28:24
# 1 2020-03-09 05:33:42           8278 2020-03-09 03:20:00 2020-03-09 05:15:00
# 2 2020-03-09 05:33:42           8278 2020-03-09 05:15:00 2020-03-09 05:33:42
# 3 2020-03-09 03:25:31            537 2020-03-09 03:20:00 2020-03-09 03:25:31
# 4 2020-03-09 03:24:54            338 2020-03-09 03:20:00 2020-03-09 03:24:54
# 5 2020-03-09 03:21:03             98 2020-03-09 03:20:00 2020-03-09 03:21:03
# 6 2020-03-09 03:29:24            125 2020-03-09 03:27:19 2020-03-09 03:29:24
# 7 2020-03-09 03:44:38            128 2020-03-09 03:42:30 2020-03-09 03:44:38
# 8 2020-03-09 03:59:41            174 2020-03-09 03:56:47 2020-03-09 03:59:41
# 9 2020-03-09 06:22:10           7801 2020-03-09 04:12:09 2020-03-09 05:15:00
#
#    overlap_s  show_duration_s  view_id  seg_idx
# 0        504             6900      183        0
# 1       6900             6900      188        0
# 2       1122             3900      188        1
# 3        331             6900      189        0
# 4        294             6900      190        0
# 5         63             6900      191        0
# 6        125             6900      192        0
# 7        128             6900      193        0
# 8        174             6900      194        0
# 9       3771             6900      195        0

# %%
joined["screen_time"] = joined["overlap_s"] / joined["show_duration_s"]


# 1) Làm sạch screen_time trong [0,1]
st = pd.to_numeric(joined["screen_time"], errors="coerce")
st = st[(st >= 0) & (st <= 1)].dropna()

print("Tóm tắt screen_time:")
print(st.describe(percentiles=[.25,.5,.75,.9,.95,.99]))

# 2) Histogram (0→1, bước 0.05)
plt.figure(figsize=(8,5))
bins = np.linspace(0, 1, 21)  # 0.00, 0.05, ..., 1.00
plt.hist(st, bins=bins, edgecolor="black", density=False)
plt.title("Histogram of screen_time (0–1)")
plt.xlabel("screen_time")
plt.ylabel("count")
plt.xlim(0, 1)
plt.tight_layout()
plt.show()

# (tuỳ chọn) Histogram dạng mật độ
plt.figure(figsize=(8,5))
plt.hist(st, bins=bins, edgecolor="black", density=True)
plt.title("Histogram of screen_time (density)")
plt.xlabel("screen_time")
plt.ylabel("density")
plt.xlim(0, 1)
plt.tight_layout()
plt.show()
# Out:
# Tóm tắt screen_time:
# count    7.752424e+06
# mean     3.060664e-01
# std      3.515854e-01
# min      3.436426e-05
# 25%      3.444444e-02
# 50%      1.283333e-01
# 75%      4.970000e-01
# 90%      1.000000e+00
# 95%      1.000000e+00
# 99%      1.000000e+00
# max      1.000000e+00
# Name: screen_time, dtype: float64

# %%
joined.columns
# Out:
# Index(['user_id', 'tv_show_id', 'vsetv_id', 'start_time_view', 'end_time_view',
#        'duration_view', 'seg_start', 'seg_end', 'overlap_s', 'show_duration_s',
#        'view_id', 'seg_idx', 'screen_time'],
#       dtype='object')

# %%
joined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752424 entries, 0 to 7752423
# Data columns (total 13 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   user_id          uint64
#  1   tv_show_id       int64
#  2   vsetv_id         int64
#  3   start_time_view  datetime64[ns]
#  4   end_time_view    datetime64[ns]
#  5   duration_view    int64
#  6   seg_start        datetime64[ns]
#  7   seg_end          datetime64[ns]
#  8   overlap_s        int64
#  9   show_duration_s  int64
#  10  view_id          int64
#  11  seg_idx          int64
#  12  screen_time      float64
# dtypes: datetime64[ns](4), float64(1), int64(7), uint64(1)
# memory usage: 768.9 MB

# %% [markdown]
# ## Loai cac chuong trinh ma co screen time thap
# - Chương trình ngắn → cần tỷ lệ cao (nếu không rất dễ “xem lướt”).
# - Chương trình dài → tỷ lệ có thể thấp hơn, nhưng vẫn cần số phút tối thiểu đủ lớn.
#
# - Theo phần trăm (tỷ lệ) – ngưỡng phụ thuộc show_duration_minutes:
#     - < 15 phút → screen_time ≥ 0.80
#     - 15–30 → screen_time ≥ 0.70
#     - 30–60 → screen_time ≥ 0.60
#     - 60–120 → screen_time ≥ 0.50
#     - > 120 → screen_time ≥ 0.50

# %%
import numpy as np
import pandas as pd

def apply_adaptive_screen_time_filter(
    df: pd.DataFrame,
    st_col: str = "screen_time",
    ovl_s_col: str = "overlap_s",
    showdur_s_col: str = "show_duration_s",
):
    # Kiểm tra cột bắt buộc
    required = {st_col, ovl_s_col, showdur_s_col}
    missing = required - set(df.columns)
    if missing:
        raise ValueError(f"Thiếu cột: {missing}")

    out = df.copy()

    # Làm sạch nhẹ
    out[st_col] = pd.to_numeric(out[st_col], errors="coerce")
    out[ovl_s_col] = pd.to_numeric(out[ovl_s_col], errors="coerce")
    out[showdur_s_col] = pd.to_numeric(out[showdur_s_col], errors="coerce")

    # chuẩn bị phút
    dur_min = out[showdur_s_col] / 60.0
    ovl_min = out[ovl_s_col] / 60.0

    # --- Ngưỡng theo TỶ LỆ (bạn yêu cầu) ---
    pct_thresh = np.select(
        [   (dur_min < 10),
            (dur_min >= 10) & (dur_min < 30),
            (dur_min >= 30) & (dur_min < 60),
            (dur_min >= 60) & (dur_min < 90),
            (dur_min >= 90) & (dur_min < 180),
            (dur_min >= 180) & (dur_min < 300),
            (dur_min >= 300)
        ],
        [ 0.8, 0.7, 0.50, 0.3, 0.25, 0.2, 0.1],
    )
    cond_pct = out[st_col] >= pct_thresh

    min_minutes = np.select(
        [   (dur_min < 30),
            (dur_min >= 30) & (dur_min < 60),
            (dur_min >= 60) & (dur_min < 120),
            (dur_min >= 120),
        ],
        [15, 20, 30, 40],
    )
    cond_abs = ovl_min >= min_minutes

    # keep nếu đạt 1 trong 2 điều kiện
    keep = cond_pct | cond_abs

    # Chặn case dữ liệu lỗi
    keep &= out[showdur_s_col] > 0
    keep &= out[st_col].between(0, 1, inclusive="both")

    out["keep"] = keep
    eligible = out[out["keep"]].copy()
    return eligible, out


eligible, joined_with_flag = apply_adaptive_screen_time_filter(joined)

rate = joined_with_flag["keep"].mean() * 100
print(f"Kept: {rate:.2f}%  |  rows kept: {eligible.shape[0]:,} / {joined_with_flag.shape[0]:,}")

# đảm bảo mỗi user đủ ≥5 show
enough_users = eligible.groupby("user_id")["tv_show_id"].nunique().ge(5).mean() * 100
print(f"Tỉ lệ user còn ≥5 chương trình: {enough_users:.2f}%")
# Out:
# Kept: 31.02%  |  rows kept: 2,404,952 / 7,752,424
# Tỉ lệ user còn ≥5 chương trình: 98.67%

# %%
total_users = eligible["user_id"].nunique()
print(f"Tổng user: {total_users:,}")
# Out:
# Tổng user: 4,897

# %%
eligible.shape
# Out:
# (2404952, 14)

# %%
eligible.columns
# Out:
# Index(['user_id', 'tv_show_id', 'vsetv_id', 'start_time_view', 'end_time_view',
#        'duration_view', 'seg_start', 'seg_end', 'overlap_s', 'show_duration_s',
#        'view_id', 'seg_idx', 'screen_time', 'keep'],
#       dtype='object')

# %%
eligible.head(5)
# Out:
#                  user_id  tv_show_id  vsetv_id     start_time_view  \
# 1   16732082036693231547     5200464         6 2020-03-09 03:15:44
# 9   16424897552696285989     5200464         6 2020-03-09 04:12:09
# 10  16424897552696285989    10002893         6 2020-03-09 04:12:09
# 23  13866173795451203812    10002893         6 2020-03-09 05:12:09
# 26   7950388484859393831    10002893         6 2020-03-09 05:18:06
#
#          end_time_view  duration_view           seg_start             seg_end  \
# 1  2020-03-09 05:33:42           8278 2020-03-09 03:20:00 2020-03-09 05:15:00
# 9  2020-03-09 06:22:10           7801 2020-03-09 04:12:09 2020-03-09 05:15:00
# 10 2020-03-09 06:22:10           7801 2020-03-09 05:15:00 2020-03-09 06:20:00
# 23 2020-03-09 06:42:58           5449 2020-03-09 05:15:00 2020-03-09 06:20:00
# 26 2020-03-09 06:03:00           2694 2020-03-09 05:18:06 2020-03-09 06:03:00
#
#     overlap_s  show_duration_s  view_id  seg_idx  screen_time  keep
# 1        6900             6900      188        0     1.000000  True
# 9        3771             6900      195        0     0.546522  True
# 10       3900             3900      195        1     1.000000  True
# 23       3900             3900      206        1     1.000000  True
# 26       2694             3900      208        0     0.690769  True

# %% [markdown]
# # Add session
# - Nhóm các lượt xem liên tiếp thành một “phiên” (session) theo khoảng trống thời gian (ví dụ >45’ thì coi là phiên mới).
# - Hiểu đúng ngữ cảnh hành vi: trong một phiên người dùng thường có cùng mục đích (xem thời sự tối, xem phim tối CN…), nên tín hiệu liên quan – khác với các lượt xem rời rạc ở các ngày khác.
# - Tạo đặc trưng mạnh theo phiên: tổng thời lượng, số kênh/chương trình khác nhau, chương trình cuối phiên, tần suất chuyển kênh, thời gian trong ngày của phiên…
# - Lấy mẫu dữ liệu thông minh: chọn positive/negative trong/khác phiên cho học xếp hạng hoặc học tương phản.
# - Tránh rò rỉ thời gian khi chia dữ liệu: split train/val theo mốc thời gian/tuần, còn session_id giúp bạn đảm bảo không cắt đôi một phiên.
# - Làm input cho mô hình chuỗi (RNN/Transformer): mỗi phiên là một sequence ngắn gọn, ít nhiễu “zapping”.

# %%
# 1) Gắn session theo gap thời gian (mặc định: 45 phút)
def add_sessions(df: pd.DataFrame,
                 user_col="user_id",
                 ts_col="start_time_view",
                 gap_min: int = 45,
                 session_col="session_id") -> pd.DataFrame:
    out = df.copy()
    out[ts_col] = pd.to_datetime(out[ts_col], errors="raise")
    out = out.sort_values([user_col, ts_col], kind="mergesort")
    gap_s = out.groupby(user_col)[ts_col].diff().dt.total_seconds().fillna(np.inf)
    new_sess = (gap_s > gap_min * 60).astype(int)
    out[session_col] = new_sess.groupby(out[user_col]).cumsum()
    return out

# %%
eligible = add_sessions(eligible, user_col="user_id",
                           ts_col="start_time_view", gap_min=45)

print(f"users: {eligible['user_id'].nunique():,} | "
      f"sessions: {eligible[['user_id','session_id']].drop_duplicates().shape[0]:,}")
# Out:
# users: 4,897 | sessions: 1,109,769

# %%
eligible.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2404952 entries, 1659674 to 6898537
# Data columns (total 15 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   user_id          uint64
#  1   tv_show_id       int64
#  2   vsetv_id         int64
#  3   start_time_view  datetime64[ns]
#  4   end_time_view    datetime64[ns]
#  5   duration_view    int64
#  6   seg_start        datetime64[ns]
#  7   seg_end          datetime64[ns]
#  8   overlap_s        int64
#  9   show_duration_s  int64
#  10  view_id          int64
#  11  seg_idx          int64
#  12  screen_time      float64
#  13  keep             bool
#  14  session_id       int64
# dtypes: bool(1), datetime64[ns](4), float64(1), int64(8), uint64(1)
# memory usage: 277.5 MB

# %%
def shrink_logs(eligible: pd.DataFrame) -> pd.DataFrame:
    keep_cols = [
        "user_id",
        "tv_show_id",
        "vsetv_id",
        "start_time_view",
        "end_time_view",
        "duration_view",
        "screen_time",
        "session_id",
    ]
    return eligible[keep_cols].copy()


logs_clean = shrink_logs(eligible)

# %%
logs_clean.head(5)
# Out:
#                   user_id  tv_show_id  vsetv_id     start_time_view  \
# 1659674  2244466330591177           0       397 2020-03-09 08:45:54
# 1887834  2244466330591177    12002107       843 2020-03-09 09:15:43
# 6130039  2244466330591177           0        20 2020-03-09 09:36:00
# 1889964  2244466330591177    12002107       843 2020-03-12 08:42:22
# 2009176  2244466330591177      240081         5 2020-03-13 18:27:58
#
#               end_time_view  duration_view  screen_time  session_id
# 1659674 2020-03-09 09:15:03           1749     0.501667           1
# 1887834 2020-03-09 09:35:54           1211     0.403667           1
# 6130039 2020-03-09 10:04:24           1704     0.258182           1
# 1889964 2020-03-12 09:49:53           4051     1.000000           2
# 2009176 2020-03-13 19:35:11           4033     1.000000           3

# %% [markdown]
# # Tao output train/val

# %%
def split_by_weeks(df: pd.DataFrame,
                   ts_col="start_time_view",
                   train_weeks=(11, 24),
                   val_weeks=(25, 30)) -> tuple[pd.DataFrame, pd.DataFrame]:
    out = df.copy()
    out[ts_col] = pd.to_datetime(out[ts_col], errors="raise")
    # ISO week (1..53); nếu dữ liệu trải qua nhiều năm, nên kèm cả year:
    iso = out[ts_col].dt.isocalendar()
    out["iso_year"] = iso.year
    out["iso_week"] = iso.week

    tr_lo, tr_hi = train_weeks
    va_lo, va_hi = val_weeks

    train = out[(out["iso_week"] >= tr_lo) & (out["iso_week"] <= tr_hi)].copy()
    val   = out[(out["iso_week"] >= va_lo) & (out["iso_week"] <= va_hi)].copy()
    return train, val

# %%
logs_train_df, logs_val_df = split_by_weeks(logs_clean,
                                  ts_col="start_time_view",
                                  train_weeks=(11,26),
                                  val_weeks=(27,30))

print(f"train: {logs_train_df.shape} | val: {logs_val_df.shape}")
# Out:
# train: (1878969, 10) | val: (525983, 10)

# %%
# ---- Robust project root detection ----
def get_project_root() -> Path:
    # 1) Script mode
    if "__file__" in globals():
        return Path(__file__).resolve().parents[1]  # src/.. -> project root
    # 2) Notebook/REPL: dò từ CWD ngược lên cho đến khi thấy both 'data' và 'src'
    cwd = Path.cwd().resolve()
    for p in [cwd, *cwd.parents]:
        if (p / "data").exists() and (p / "src").exists():
            return p
    # 3) Fallback: dùng CWD
    return cwd

PROJECT_ROOT = get_project_root()
DATA_DIR = PROJECT_ROOT / "data" / "clean"   # hoặc "clean" nếu bạn muốn
DATA_DIR.mkdir(parents=True, exist_ok=True)

OUT_TRAIN = DATA_DIR / "logs_train.parquet"
OUT_VAL   = DATA_DIR / "logs_val.parquet"

# %%
logs_train_df.to_parquet(OUT_TRAIN, index=False)
logs_val_df.to_parquet(OUT_VAL, index=False)

# %% [markdown]
# # Xu ly data test

# %%
metadata_test = r"C:\bachkhoahanoi\2025.1\Recommend System\data\raw\sweettv-tv-program-recommender\export_arh_31-42-final.csv"
metadata_test = read_csv(metadata_test)
metadata_test.head(10)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12100\432394216.py:9: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(path, **kw)
#    channel_id channel_title           start_time  duration  \
# 0           3           1+1  27.07.2020 06:30:00      1800
# 1           3           1+1  27.07.2020 07:00:00       600
# 2           3           1+1  27.07.2020 07:10:00      3000
# 3           3           1+1  27.07.2020 08:00:00       600
# 4           3           1+1  27.07.2020 08:10:00      3000
# 5           3           1+1  27.07.2020 09:00:00       600
# 6           3           1+1  27.07.2020 09:10:00       900
# 7           3           1+1  27.07.2020 09:25:00      3600
# 8           3           1+1  27.07.2020 10:25:00      3600
# 9           3           1+1  27.07.2020 11:25:00      6900
#
#                                        tv_show_title  tv_show_id  \
# 0  'Завтрак с 1+1'. Информационно-развлекательная...       20088
# 1                                               ТСН.     2400480
# 2  'Завтрак с 1+1'. Информационно-развлекательная...       20088
# 3                                               ТСН.     2400480
# 4  'Завтрак с 1+1'. Информационно-развлекательная...       20088
# 5                                               ТСН.     2400480
# 6  'Завтрак с 1+1'. Информационно-развлекательная...       20088
# 7           'Жизнь известных людей', 2 сезон, 59 эп.           0
# 8           'Жизнь известных людей', 1 сезон, 15 эп.           0
# 9             'Рассмеши комика', 16 сезон, 7 и 8 эп.      700382
#
#   tv_show_category           tv_show_genre_1 tv_show_genre_2 tv_show_genre_3  \
# 0      Развлечения  информация (комплексная)             NaN             NaN
# 1             Инфо       общество и политика             NaN             NaN
# 2      Развлечения  информация (комплексная)             NaN             NaN
# 3             Инфо       общество и политика             NaN             NaN
# 4      Развлечения  информация (комплексная)             NaN             NaN
# 5             Инфо       общество и политика             NaN             NaN
# 6      Развлечения  информация (комплексная)             NaN             NaN
# 7           Другое                       NaN             NaN             NaN
# 8           Другое                       NaN             NaN             NaN
# 9      Развлечения                      юмор             NaN             NaN
#
#   year_of_production director actors
# 0              1996-      NaN    NaN
# 1               1997      NaN    NaN
# 2              1996-      NaN    NaN
# 3               1997      NaN    NaN
# 4              1996-      NaN    NaN
# 5               1997      NaN    NaN
# 6              1996-      NaN    NaN
# 7                NaN      NaN    NaN
# 8                NaN      NaN    NaN
# 9              2011-      NaN    NaN

# %%
metadata_test_df = load_meta([metadata_test])

# %%
metadata_test_df.shape
# Out:
# (1295378, 10)

# %%
metadata_test_df.head(5)
# Out:
#    vsetv_id  tv_show_id tv_show_category director  \
# 0         3       20088      Развлечения      NaN
# 1         3     2400480             Инфо      NaN
# 2         3       20088      Развлечения      NaN
# 3         3     2400480             Инфо      NaN
# 4         3       20088      Развлечения      NaN
#
#                             genres_list actors_list          start_time  \
# 0  [информация (комплексная), nan, nan]          [] 2020-07-27 06:30:00
# 1       [общество и политика, nan, nan]          [] 2020-07-27 07:00:00
# 2  [информация (комплексная), nan, nan]          [] 2020-07-27 07:10:00
# 3       [общество и политика, nan, nan]          [] 2020-07-27 08:00:00
# 4  [информация (комплексная), nan, nan]          [] 2020-07-27 08:10:00
#
#              prog_end  duration year_of_production
# 0 2020-07-27 07:00:00      1800              1996-
# 1 2020-07-27 07:10:00       600               1997
# 2 2020-07-27 08:00:00      3000              1996-
# 3 2020-07-27 08:10:00       600               1997
# 4 2020-07-27 09:00:00      3000              1996-

# %%
out_test   = DATA_DIR / "metadata_test.parquet"

metadata_test_df.to_parquet(out_test, index=False)
# Out:
# ---------------------------------------------------------------------------
# ArrowTypeError                            Traceback (most recent call last)
# Cell In[55], line 3
#       1 out_test   = DATA_DIR / "metadata_test.parquet"
# ----> 3 metadata_test_df.to_parquet(out_test, index=False)
#
# File c:\bachkhoahanoi\2025.1\Recommend System\.venv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\bachkhoahanoi\2025.1\Recommend System\.venv\Lib\site-packages\pandas\core\frame.py:3124, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    3043 """
#    3044 Write a DataFrame to the binary parquet format.
#    3045
#    (...)   3120 >>> content = f.read()
#    3121 """
#    3122 from pandas.io.parquet import to_parquet
# -> 3124 return to_parquet(
#    3125     self,
#    3126     path,
#    3127     engine,
#    3128     compression=compression,
#    3129     index=index,
#    3130     partition_cols=partition_cols,
#    3131     storage_options=storage_options,
#    3132     **kwargs,
#    3133 )
#
# File c:\bachkhoahanoi\2025.1\Recommend System\.venv\Lib\site-packages\pandas\io\parquet.py:482, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     478 impl = get_engine(engine)
#     480 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
# --> 482 impl.write(
#     483     df,
#     484     path_or_buf,
#     485     compression=compression,
#     486     index=index,
#     487     partition_cols=partition_cols,
#     488     storage_options=storage_options,
#     489     filesystem=filesystem,
#     490     **kwargs,
#     491 )
#     493 if path is None:
#     494     assert isinstance(path_or_buf, io.BytesIO)
#
# File c:\bachkhoahanoi\2025.1\Recommend System\.venv\Lib\site-packages\pandas\io\parquet.py:191, in PyArrowImpl.write(self, df, path, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     188 if index is not None:
#     189     from_pandas_kwargs["preserve_index"] = index
# --> 191 table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
#     193 if df.attrs:
#     194     df_metadata = {"PANDAS_ATTRS": json.dumps(df.attrs)}
#
# File c:\bachkhoahanoi\2025.1\Recommend System\.venv\Lib\site-packages\pyarrow\table.pxi:4795, in pyarrow.lib.Table.from_pandas()
#
# File c:\bachkhoahanoi\2025.1\Recommend System\.venv\Lib\site-packages\pyarrow\pandas_compat.py:650, in dataframe_to_arrays(df, schema, preserve_index, nthreads, columns, safe)
#     648     for i, maybe_fut in enumerate(arrays):
#     649         if isinstance(maybe_fut, futures.Future):
# --> 650             arrays[i] = maybe_fut.result()
#     652 types = [x.type for x in arrays]
#     654 if schema is None:
#
# File ~\miniconda3\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\miniconda3\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\miniconda3\Lib\concurrent\futures\thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File c:\bachkhoahanoi\2025.1\Recommend System\.venv\Lib\site-packages\pyarrow\pandas_compat.py:625, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     620 except (pa.ArrowInvalid,
#     621         pa.ArrowNotImplementedError,
#     622         pa.ArrowTypeError) as e:
#     623     e.args += (
#     624         f"Conversion failed for column {col.name} with type {col.dtype}",)
# --> 625     raise e
#     626 if not field_nullable and result.null_count > 0:
#     627     raise ValueError(f"Field {field} was non-nullable but pandas column "
#     628                      f"had {result.null_count} null values")
#
# File c:\bachkhoahanoi\2025.1\Recommend System\.venv\Lib\site-packages\pyarrow\pandas_compat.py:619, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     616     type_ = field.type
#     618 try:
# --> 619     result = pa.array(col, type=type_, from_pandas=True, safe=safe)
#     620 except (pa.ArrowInvalid,
#     621         pa.ArrowNotImplementedError,
#     622         pa.ArrowTypeError) as e:
#     623     e.args += (
#     624         f"Conversion failed for column {col.name} with type {col.dtype}",)
#
# File c:\bachkhoahanoi\2025.1\Recommend System\.venv\Lib\site-packages\pyarrow\array.pxi:365, in pyarrow.lib.array()
#
# File c:\bachkhoahanoi\2025.1\Recommend System\.venv\Lib\site-packages\pyarrow\array.pxi:91, in pyarrow.lib._ndarray_to_array()
#
# File c:\bachkhoahanoi\2025.1\Recommend System\.venv\Lib\site-packages\pyarrow\error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowTypeError: ("Expected bytes, got a 'float' object", 'Conversion failed for column year_of_production with type object')
